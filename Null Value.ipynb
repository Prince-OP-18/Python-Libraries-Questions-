# %%
import pandas as pd
df=pd.read_csv("/Users/princu_67/Downloads/Diabetes Missing Data.csv")
df.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
df.fillna({"Serum_Insulin":0,"Skin_Fold":"No Skin Fold"})
# Out:
#      Pregnant  Glucose  Diastolic_BP     Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0          35.0            0.0  33.6
# 1           1     85.0          66.0          29.0            0.0  26.6
# 2           8    183.0          64.0  No Skin Fold            0.0  23.3
# 3           1     89.0          66.0          23.0           94.0  28.1
# 4           0    137.0          40.0          35.0          168.0  43.1
# ..        ...      ...           ...           ...            ...   ...
# 763        10    101.0          76.0          48.0          180.0  32.9
# 764         2    122.0          70.0          27.0            0.0  36.8
# 765         5    121.0          72.0          23.0          112.0  26.2
# 766         1    126.0          60.0  No Skin Fold            0.0  30.1
# 767         1     93.0          70.0          31.0            0.0  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# ...

# %%
#Entry of previous entries
df.ffill()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0       29.0            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0          180.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0       23.0          112.0  30.1
# 767         1     93.0          70.0       31.0          112.0  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
#Entry of next entries 
df.bfill()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0           94.0  33.6
# 1           1     85.0          66.0       29.0           94.0  26.6
# 2           8    183.0          64.0       23.0           94.0  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0          112.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0       31.0            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
#To copy the entry only once 
df.bfill(limit=1)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0       23.0           94.0  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0          112.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0       31.0            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
#To fill the NaN value with the average of 2 values
df.interpolate().head(10)
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.60
# 1         1     85.0          66.0       29.0            NaN  26.60
# 2         8    183.0          64.0       26.0            NaN  23.30
# 3         1     89.0          66.0       23.0           94.0  28.10
# 4         0    137.0          40.0       35.0          168.0  43.10
# 5         5    116.0          74.0       33.5          128.0  25.60
# 6         3     78.0          50.0       32.0           88.0  31.00
# 7        10    115.0          60.0       38.5          315.5  35.30
# 8         2    197.0          70.0       45.0          543.0  30.50
# 9         8    125.0          96.0       40.6          603.6  34.05
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# ...
